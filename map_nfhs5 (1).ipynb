# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
map1 = pd.read_csv('map_nfhs5_final_22-3-25.csv')

# %%
map1.columns
# Out:
# Index(['hv024', 'hv025', 'hv201', 'hv205', 'hv206', 'hv207', 'hv208', 'hv209',
#        'hv210', 'hv211', 'hv212', 'hv221', 'hv226', 'hv243a', 'hv243e',
#        'hv247', 'hv270', 'shdist', 'sh47', 'sh49', 'shstruc', 'hv104', 'hv106',
#        'hv115', 'sh26', 'shb15', 'shb19', 'shb20', 'shb21', 'systolic',
#        'diastolic', 'MAP', 'shb55', 'shb56', 'shb57', 'shb74', 'sh305',
#        'sh306', 'ha35', 'ha40', 'ha53', 'hml16'],
#       dtype='object')

# %%
columns = map1.columns
print(columns)
# Out:
# Index(['hv024', 'hv025', 'hv201', 'hv205', 'hv206', 'hv207', 'hv208', 'hv209',
#        'hv210', 'hv211', 'hv212', 'hv221', 'hv226', 'hv243a', 'hv243e',
#        'hv247', 'hv270', 'shdist', 'sh47', 'sh49', 'shstruc', 'hv104', 'hv106',
#        'hv115', 'sh26', 'shb15', 'shb19', 'shb20', 'shb21', 'systolic',
#        'diastolic', 'MAP', 'shb55', 'shb56', 'shb57', 'shb74', 'sh305',
#        'sh306', 'ha35', 'ha40', 'ha53', 'hml16'],
#       dtype='object')

# %%
# Short names mapping
short_names = {
     "hv024": "State",
    "hv025": "ResidenceType",
    "hv201": "DrinkingWater",
    "hv205": "ToiletFacility",
    "hv206": "Electricity",
    "hv207": "Radio",
    "hv208": "TV",
    "hv209": "Refrigerator",
    "hv210": "Bicycle",
    "hv211": "Motorcycle",
    "hv212": "CarTruck",
    "hv221": "Telephone",
    "hv226": "CookingFuel",
    "hv243a": "MobilePhone",
    "hv243e": "Computer",
    "hv247": "BankAccount",
    "hv270": "WealthIndex",
    "shdist": "District",
    "sh47": "Religion",
    "sh49": "CasteCategory",
    "shstruc": "HouseholdStructure",
    "hv104": "Sex",
    "hv106": "EducationLevel",
    "hv115": "MaritalStatus",
    "sh26": "AlcoholUse",
    "shb15": "ArmCircumference",
    "shb19": "BPAwareness",
    "shb20": "BPScreening",
    "shb21": "BPTreatment",
    "systolic": "SystolicBP",
    "diastolic": "DiastolicBP",
    "MAP": "meap",
    "shb55": "GlucoseAwareness",
    "shb56": "GlucoseScreening",
    "shb57": "GlucoseTreatment",
    "shb74": "GlucoseLevel",
    "sh305": "WaistCircumference",
    "sh306": "HipCircumference",
    "ha35": "Smoking",
    "ha40": "BMI",
    "ha53": "Hemoglobin",
    "hml16": "Age"
}

# %%
# Rename columns to short names
#df.rename(columns=short_names, inplace=True)

map1.rename (columns = short_names,inplace=True)

# %%
print(map1)
# Out:
#         State  ResidenceType  DrinkingWater  ToiletFacility  Electricity  \
# 0           1              2             14            12.0            1
# 1           1              2             14            12.0            1
# 2           1              2             14            44.0            1
# 3           1              2             14            12.0            1
# 4           1              2             14            12.0            1
# ...       ...            ...            ...             ...          ...
# 739792     37              1             61            12.0            1
# 739793     37              1             61            12.0            1
# 739794     37              1             61            12.0            1
# 739795     37              1             61            12.0            1
# 739796     37              1             61            12.0            1
#
#         Radio  TV  Refrigerator  Bicycle  Motorcycle  ...  GlucoseAwareness  \
# ...

# %%
map1.columns
# Out:
# Index(['State', 'ResidenceType', 'DrinkingWater', 'ToiletFacility',
#        'Electricity', 'Radio', 'TV', 'Refrigerator', 'Bicycle', 'Motorcycle',
#        'CarTruck', 'Telephone', 'CookingFuel', 'MobilePhone', 'Computer',
#        'BankAccount', 'WealthIndex', 'District', 'Religion', 'CasteCategory',
#        'HouseholdStructure', 'Sex', 'EducationLevel', 'MaritalStatus',
#        'AlcoholUse', 'ArmCircumference', 'BPAwareness', 'BPScreening',
#        'BPTreatment', 'SystolicBP', 'DiastolicBP', 'meap', 'GlucoseAwareness',
#        'GlucoseScreening', 'GlucoseTreatment', 'GlucoseLevel',
#        'WaistCircumference', 'HipCircumference', 'Smoking', 'BMI',
#        'Hemoglobin', 'Age'],
#       dtype='object')

# %%
map1 = map1.astype({
    "State": "category",
    "ResidenceType": "category",
    "DrinkingWater": "category",
    "ToiletFacility": "category",
    "Electricity": "category",
    "Radio": "category",
    "TV": "category",
    "Refrigerator": "category",
    "Bicycle": "category",
    "Motorcycle": "category",
    "CarTruck": "category",
    "Telephone": "category",
    "CookingFuel": "category",
    "MobilePhone": "category",
    "Computer": "category",
    "BankAccount": "category",
    "WealthIndex": "category",
    "District": "category",
    "Religion": "category",
    "CasteCategory": "category",
    "HouseholdStructure": "category",
    "Sex": "category",
    "EducationLevel": "category",
    "MaritalStatus": "category",
    "AlcoholUse": "category",
    "Smoking": "category",
    "BPAwareness": "category",
    "BPScreening": "Int64",
    "BPTreatment": "Int64",
    "SystolicBP": "float64",
    "DiastolicBP": "float64",
    "meap": "float64",
    "GlucoseAwareness": "Int64",
    "GlucoseScreening": "Int64",
    "GlucoseTreatment": "Int64",
    "GlucoseLevel": "float64",
    "WaistCircumference": "float64",
    "HipCircumference": "float64",
    "BMI": "float64",
    "Age": "Int64",
    "ArmCircumference": "float64",
    "Hemoglobin": "float64"
})

# %%
map1.describe()
# Out:
#        ArmCircumference  BPScreening  BPTreatment     SystolicBP  \
# count     350820.000000     350822.0     350750.0  350827.000000
# mean          24.806228     0.076449     0.026004     118.221907
# std            3.056134     0.265716     0.159148      13.138227
# min            5.000000          0.0          0.0      70.000000
# 25%           23.000000          0.0          0.0     109.000000
# 50%           24.000000          0.0          0.0     117.666660
# 75%           27.000000          0.0          0.0     125.666660
# max           80.000000          1.0          1.0     208.000000
#
#          DiastolicBP           meap  GlucoseAwareness  GlucoseScreening  \
# count  350827.000000  350827.000000          349887.0          349887.0
# mean       78.589392      91.800230          0.261053            0.0178
# std         8.985936       9.586137          0.439209          0.132224
# min        45.000000      56.111111               0.0               0.0
# ...

# %%
map1.shape
# Out:
# (350827, 42)

# %%
map1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350827 entries, 0 to 350826
# Data columns (total 42 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   State               350827 non-null  category
#  1   ResidenceType       350827 non-null  category
#  2   DrinkingWater       350827 non-null  category
#  3   ToiletFacility      350827 non-null  category
#  4   Electricity         350827 non-null  category
#  5   Radio               350827 non-null  category
#  6   TV                  350827 non-null  category
#  7   Refrigerator        350827 non-null  category
#  8   Bicycle             350827 non-null  category
#  9   Motorcycle          350827 non-null  category
#  10  CarTruck            350827 non-null  category
#  11  Telephone           350827 non-null  category
#  12  CookingFuel         350827 non-null  category
#  13  MobilePhone         350827 non-null  category
# ...

# %%
map1['Hemoglobin'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 350827 entries, 0 to 350826
# Series name: Hemoglobin
# Non-Null Count   Dtype
# --------------   -----
# 309789 non-null  float64
# dtypes: float64(1)
# memory usage: 2.7 MB

# %%
map1.isnull().sum()
# Out:
# State                 0
# ResidenceType         0
# DrinkingWater         0
# ToiletFacility        0
# Electricity           0
# Radio                 0
# TV                    0
# Refrigerator          0
# Bicycle               0
# Motorcycle            0
# CarTruck              0
# Telephone             0
# CookingFuel           0
# MobilePhone           0
# Computer              0
# BankAccount           0
# WealthIndex           0
# District              0
# Religion              0
# CasteCategory         0
# HouseholdStructure    0
# Sex                   0
# EducationLevel        0
# MaritalStatus         0
# AlcoholUse            0
# ArmCircumference      0
# BPAwareness           0
# BPScreening           0
# BPTreatment           0
# SystolicBP            0
# DiastolicBP           0
# meap                  0
# GlucoseAwareness      0
# GlucoseScreening      0
# GlucoseTreatment      0
# GlucoseLevel          0
# WaistCircumference    0
# HipCircumference      0
# ...

# %%
# prompt: fill na bmi from the mean bmi

# Fill NA values in 'BMI' column with the mean BMI
map1['BMI'].fillna(map1['BMI'].mean(), inplace=True)
# Out:
# <ipython-input-14-bc7d51afce91>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   map1['BMI'].fillna(map1['BMI'].mean(), inplace=True)

# %%
# prompt: drop if the haemoglobin is more than 200

# Drop rows where Hemoglobin is greater than 200
map1 = map1.drop(map1[map1['Hemoglobin'] > 200].index)

# %%
# prompt: drop all the null values

# Drop rows with any null values
map1.dropna(inplace=True)

# %%
sns.boxplot(x=map1['BMI'])
# Out:
# <Axes: xlabel='BMI'>

# %%
# prompt: drop BMI which is more than 3200

# Drop rows where BMI is greater than 3200
map1 = map1.drop(map1[map1['BMI'] > 3100].index)

# %%
map1['BMI'] = map1['BMI']/100

# %%
# prompt: can we do a corr plot in respect to meap

import matplotlib.pyplot as plt
# Assuming 'map1' DataFrame is already processed as in the provided code.

plt.figure(figsize=(12, 10))
sns.heatmap(map1.corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Matrix of Features')
plt.show()

# Correlation with 'meap' specifically
correlation_with_meap = map1.corr()['meap'].sort_values(ascending=False)
print("\nCorrelation with 'meap':\n", correlation_with_meap)
# Out:
# Correlation with 'meap':
#  meap                  1.000000
# DiastolicBP           0.945048
# SystolicBP            0.893602
# Age                   0.355427
# BMI                   0.310148
# ArmCircumference      0.269539
# WaistCircumference    0.265094
# HipCircumference      0.210468
# MaritalStatus         0.169329
# Hemoglobin            0.167908
# BPScreening           0.128690
# GlucoseLevel          0.122604
# BPAwareness           0.108916
# GlucoseAwareness      0.101904
# BPTreatment           0.101842
# TV                    0.062150
# WealthIndex           0.058417
# GlucoseScreening      0.057876
# AlcoholUse            0.054976
# Religion              0.050812
# GlucoseTreatment      0.043449
# Refrigerator          0.043128
# CarTruck              0.040594
# Motorcycle            0.030621
# Radio                 0.028189
# District              0.025811
# Computer              0.021193
# CasteCategory         0.015538
# Telephone             0.011042
# ...

# %%
# prompt: now genrate a linear model

from sklearn.linear_model import LinearRegression

# Initialize the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model (example: using R-squared)
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.9999999999999174

# %%
# prompt: visualize this model

import pandas as pd
# Assuming 'map1' is your DataFrame after preprocessing and model training
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the distribution of the target variable 'BMI'
plt.figure(figsize=(8, 6))
sns.histplot(map1['BMI'], kde=True)
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# Visualize the relationship between features and BMI (example: scatter plots)
# Select a few relevant features
features_to_plot = ['Age', 'Hemoglobin', 'WaistCircumference', 'SystolicBP']  # Replace with relevant columns

plt.figure(figsize=(15, 10))
for i, feature in enumerate(features_to_plot):
    plt.subplot(2, 2, i+1)
    sns.scatterplot(x=map1[feature], y=map1['BMI'])
    plt.title(f'BMI vs. {feature}')
plt.tight_layout()
plt.show()


# Visualize feature importances (if applicable, e.g., for tree-based models)
# Example for a linear regression model (coefficients as importance)
importances = model.coef_
feature_names = X.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# Residual plot
residuals = y_test - y_pred
plt.figure(figsize=(8, 6))
sns.residplot(x=y_pred, y=residuals)
plt.title('Residual Plot')
plt.xlabel('Predicted BMI')
plt.ylabel('Residuals')
plt.show()
